# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosasenciom/SIM_YAC_ASENCIO_UPSE2023/blob/main/proyectmaes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import io
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cc213819-0def-49fc-887c-e70e0eaea886" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc213819-0def-49fc-887c-e70e0eaea886">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
DATAFUENTE = list(uploaded.keys())[0]  # Nombre del archivo cargado
dataF = pd.read_excel(io.BytesIO(uploaded[DATAFUENTE]))

# %%
dataF
# Out:
#      1.000000   0.052331  -0.011123
# 0           2   0.052841  -0.008369
# 1           3   0.053207  -0.005592
# 2           4   0.053427  -0.002800
# 3           5   0.053500   0.000000
# 4           6   0.053427   0.002800
# ..        ...        ...        ...
# 66         68   0.037830  -0.037830
# 67         69   0.039758  -0.035798
# 68         70   0.041577  -0.033669
# 69         71   0.043282  -0.031447
# 70         72   0.044869  -0.029138
#
# [71 rows x 3 columns]

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-96ed0546-14bf-4048-b0d3-47fd22509b10" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-96ed0546-14bf-4048-b0d3-47fd22509b10">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
DATARECEPTOR = list(uploaded.keys())[0]  # Nombre del archivo cargado
dataR = pd.read_excel(io.BytesIO(uploaded[DATARECEPTOR]))

# %%
dataR
# Out:
#      1.0000    0.0535    0.0000
# 0         2  0.053427  0.002800
# 1         3  0.053207  0.005592
# 2         4  0.052841  0.008369
# 3         5  0.052331  0.011123
# 4         6  0.051677  0.013847
# ..      ...       ...       ...
# 114     116  0.051677 -0.013847
# 115     117  0.052331 -0.011123
# 116     118  0.052841 -0.008369
# 117     119  0.053207 -0.005592
# 118     120  0.053427 -0.002800
#
# [119 rows x 3 columns]

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bdf7fd10-6bf2-4d21-b690-ef3da2ecae0e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdf7fd10-6bf2-4d21-b690-ef3da2ecae0e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
DATAOBS = list(uploaded.keys())[0]  # Nombre del archivo cargado
dataob = pd.read_excel(io.BytesIO(uploaded[DATAOBS]))

# %%
dataob
# Out:
#      1.000000    107.000000  0.000007
# 0             1         106    0.000007
# 1             1         105    0.000008
# 2             1         104    0.000009
# 3             1         103    0.000009
# 4             1         102    0.000010
# ..          ...         ...         ...
# 855          72           4    0.000009
# 856          72           3    0.000008
# 857          72           2    0.000008
# 858          72           1    0.000007
# 859          72         120    0.000006
#
# [860 rows x 3 columns]

# %%
# Emparejamiento de coordenadas
emparejamiento = pd.merge(dataob, dataF, left_on=dataob.columns[0], right_on=dataF.columns[0])
emparejamiento = pd.merge(emparejamiento, dataR, left_on=dataob.columns[1], right_on=dataR.columns[0])

# %%
emparejamiento
# Out:
#      1.0_x  107.0  6.65e-06  0.052331  -0.011123  1.0_y    0.0535       0.0
# 0        2     97  0.000013  0.052841  -0.008369     97  0.016532 -0.050882
# 1       12     97  0.000020  0.041577   0.033669     97  0.016532 -0.050882
# 2       22     97  0.000021  0.002800   0.053427     97  0.016532 -0.050882
# 3       23     97  0.000022  0.000000   0.053500     97  0.016532 -0.050882
# 4       33     97  0.000021 -0.039758   0.035798     97  0.016532 -0.050882
# ..     ...    ...       ...       ...        ...    ...       ...       ...
# 836     30      3  0.000020 -0.033669   0.041577      3  0.053207  0.005592
# 837     41      3  0.000022 -0.053500   0.000000      3  0.053207  0.005592
# 838     51      3  0.000021 -0.035798  -0.039758      3  0.053207  0.005592
# 839     62      3  0.000017  0.008369  -0.052841      3  0.053207  0.005592
# 840     72      3  0.000008  0.044869  -0.029138      3  0.053207  0.005592
#
# [841 rows x 8 columns]

# %%
emparejamiento.columns[0]
# Out:
# '1.0_x'

# %%
import pandas as pd
columnas_seleccionadas = [2, 3, 4, 6, 7]

# Crear la nueva tabla con columnas seleccionadas
nueva_tabla = emparejamiento.iloc[:, columnas_seleccionadas]

# %%
nueva_tabla
# Out:
#      6.65e-06  0.052331  -0.011123    0.0535       0.0
# 0    0.000013  0.052841  -0.008369  0.016532 -0.050882
# 1    0.000020  0.041577   0.033669  0.016532 -0.050882
# 2    0.000021  0.002800   0.053427  0.016532 -0.050882
# 3    0.000022  0.000000   0.053500  0.016532 -0.050882
# 4    0.000021 -0.039758   0.035798  0.016532 -0.050882
# ..        ...       ...        ...       ...       ...
# 836  0.000020 -0.033669   0.041577  0.053207  0.005592
# 837  0.000022 -0.053500   0.000000  0.053207  0.005592
# 838  0.000021 -0.035798  -0.039758  0.053207  0.005592
# 839  0.000017  0.008369  -0.052841  0.053207  0.005592
# 840  0.000008  0.044869  -0.029138  0.053207  0.005592
#
# [841 rows x 5 columns]

# %%
nombres_columnas = ['col1', 'col2', 'col3', 'col4', 'col5']
df = pd.DataFrame(nueva_tabla, columns=nombres_columnas)

# %%
df.shape
# Out:
# (841, 6)

# %%
df['distancia'] = df['col1'] + df['col2'] * df['col3']
df['distancia'] = ((df[_col3] - df[_col1])**2 + (df[_col5] - df[_col3])**2)**0.5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-83f61bc6b90b> in <cell line: 2>()
#       1 df['distancia'] = df['col1'] + df['col2'] * df['col3']
# ----> 2 df['distancia'] = ((df[_col3] - df[_col1])**2 + (df[_col5] - df[_col3])**2)**0.5
#
# NameError: name '_col3' is not defined
